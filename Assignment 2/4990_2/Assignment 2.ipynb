# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras as ka
import os
from sklearn.utils import shuffle
import cv2

# %%
csvfolder = "C:\\Users\\Diane\\Documents\\School\\Semester\\Fall 2018\\CS4990\\GitHub\\Machine-Learning-and-AI\\Assignment 2\\4990_2\\train_target.csv"
trainfolder = 'C:\\Users\\Diane\\Documents\\School\\Semester\\Fall 2018\\CS4990\\GitHub\\Machine-Learning-and-AI\\Assignment 2\\4990_2\\train'
file = pd.read_csv(csvfolder)
#print(file.head)  

file = shuffle(file)    #make random 

file = np.array(file)
train_data = file[:, 0]
train_target = file[:, 1]
folderimg = []   #make image folder

j=0
for i in train_data:                        #going through every item in train data
    try:
        img = os.path.join(trainfolder,i)   
        #print(img)                         #check if path is running ok
        #folderimg.append(cv2.imread(img, 0))         #store to list and read (assuming you already have cv2)
        img = cv2.imread(img, 0)
        img = cv2.resize(img, (300,300))
        folderimg.append(img)
    except:
        np.delete(train_target, j)
        pass
    j+=1

# %%
#shows pictures
'''
#print out images individually 
folderimg = []                         #make image folder

for x  in os.listdir(trainfolder):
    img = os.path.join(trainfolder, x) #join images together
    folderimg.append(img)

print(folderimg[0])
read1 = plt.imread(folderimg[0]) #reads image
plt.imshow(read1)                #shows image

read2 = plt.imread(folderimg[1])
plt.imshow(read2)
'''
# Out:
# '\n#print out images individually \nfolderimg = []                         #make image folder\n\nfor x  in os.listdir(trainfolder):\n    img = os.path.join(trainfolder, x) #join images together\n    folderimg.append(img)\n\nprint(folderimg[0])\nread1 = plt.imread(folderimg[0]) #reads image\nplt.imshow(read1)                #shows image\n\nread2 = plt.imread(folderimg[1])\nplt.imshow(read2)\n'

# %%
plt.imshow(folderimg[5])

# %%
#keras
'''
m = ka.models.Sequential()         #model
m.add(ka.layers.Dense(32))
m.add(ka.layers.Conv2D(filters = 32, kernel_size= [2,2], strides=(1, 1), padding='valid', data_format=None, dilation_rate=(1, 1), activation=None, use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, bias_constraint=None))
m.add(ka.layers.MaxPooling2D(pool_size=(2, 2), strides=(1,1), padding='valid', data_format=None))
m.add(ka.layers.Dense(5))
'''
'''
m.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
m.fit(folderimg, train_target,epochs=10, batch_size=1)
'''
# Out:
# "\nm.compile(optimizer='rmsprop',\n              loss='binary_crossentropy',\n              metrics=['accuracy'])\nm.fit(folderimg, train_target,epochs=10, batch_size=1)\n"

# %%
class CNN:
    def__initialize__(self, height, weight, c_channels):
        self.input_layer = tf.placeholder()
